# %% [markdown]
# #### ***Chains in lagchain***

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# %% [markdown]
# ##### ***first chain***

# %%
# Task-1 Prompt 

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a study assistant"),
    ("human", "{input}")
])

# %%
# Task-2 LLM

from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# %%
# Task-3 

from langchain_core.output_parsers import StrOutputParser
str_perser = StrOutputParser()

# %% [markdown]
# ### ***Manual invocation***

# %% [markdown]
# ###### template = prompt_template.invoke({"input":"Waht is todays date"})
# ###### res = model.invoke(template)
# ###### final_res = res.content

# %% [markdown]
# ### ***Chain invocation***

# %%
chain = prompt_template | model | str_perser

chain.invoke({"input": "What are chains in langchain"})
# Out:
# 'In LangChain, a Python library for building conversational AI models, a "chain" refers to a sequence of operations that are executed in a specific order to generate a response to a user input. Chains are the core building block of LangChain models, and they allow developers to define complex conversational flows and interactions.\n\nA chain typically consists of the following components:\n\n1. **Input**: The user\'s input or prompt that triggers the chain.\n2. **Operations**: A series of functions or methods that are executed in sequence to process the input and generate a response. These operations can include tasks such as:\n\t* Retrieving information from a database or API.\n\t* Performing natural language processing (NLP) tasks, such as text classification or sentiment analysis.\n\t* Generating text or responses using a language model.\n3. **Output**: The final response generated by the chain, which is returned to the user.\n\nChains can be thought of as a series of "steps" that are executed in a specific order to generate a response. Each step can be a simple function or a complex operation that involves multiple tasks.\n\nHere\'s an example of a simple chain in LangChain:\n```python\nfrom langchain.chains import LLMChain\n\n# Define a chain that takes a user input, retrieves information from a database, and generates a response\nchain = LLMChain(\n    input_keys=["user_input"],\n    llm="text-davinci-003",\n    func=lambda input_str: retrieve_info_from_db(input_str) + " This is a generated response."\n)\n\n# Define a function to retrieve information from a database\ndef retrieve_info_from_db(input_str):\n    # Simulate retrieving information from a database\n    return f"Information for {input_str} is: foo bar baz"\n\n# Execute the chain with a user input\nuser_input = "What is the capital of France?"\nresponse = chain.run(user_input)\nprint(response)  # Output: "Information for What is the capital of France? is: foo bar baz This is a generated response."\n```\nIn this example, the chain takes a user input, retrieves information from a database using the `retrieve_info_from_db` function, and generates a response using a language model. The final response is returned to the user.\n\nChains can be composed together to create more complex conversational flows, and they can be used to build a wide range of conversational AI models, from simple chatbots to more complex dialogue systems.'
