# %% [markdown]
# #### ***Chains in lagchain***

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# %% [markdown]
# ##### ***first chain***

# %%
# Task-1 Prompt 

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a study assistant"),
    ("human", "{input}")
])

# %%
# Task-2 LLM

from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.3-70b-versatile", temperature=0)

# %%
# Task-3 

from langchain_core.output_parsers import StrOutputParser
str_perser = StrOutputParser()

# %% [markdown]
# ### ***Manual invocation***

# %% [markdown]
# ###### template = prompt_template.invoke({"input":"Waht is todays date"})
# ###### res = model.invoke(template)
# ###### final_res = res.content

# %% [markdown]
# ### ***Chain invocation***

# %%
### method 1 of running a chain

chain = prompt_template | model | str_perser

chain.invoke({"input": "What are chains in langchain"})
# Out:
# 'In LangChain, a chain refers to a sequence of functions or operations that are composed together to process and transform input data, typically text. LangChain is a framework for building and composing large language models (LLMs) and other AI models to create more complex and powerful AI systems.\n\nA chain in LangChain can consist of multiple components, such as:\n\n1. **Text encoding**: converting input text into a numerical representation that can be processed by the model.\n2. **Model inference**: passing the encoded input through a language model to generate output.\n3. **Post-processing**: applying additional transformations or operations to the output, such as filtering, sorting, or formatting.\n4. **Memory retrieval**: accessing external knowledge bases or memory stores to retrieve relevant information.\n5. **Control flow**: making decisions or branching based on the output of previous components.\n\nBy chaining these components together, LangChain enables the creation of c
# ...

# %%
### Method two of runing a chain

from langchain_core.runnables import RunnableSequence

chain_1 = RunnableSequence(prompt_template, model, str_perser)
chain_1.invoke("What is todays date")
# Out:
# "Today's date is June 23, 2026."
