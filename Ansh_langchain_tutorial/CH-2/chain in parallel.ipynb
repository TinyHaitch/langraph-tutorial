# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### ***Parallel Chain***

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
#### TASK-1
prompt_template = ChatPromptTemplate([
    ("system", "You are a study assistant"),
    ("human", "{input}")
])

# %%
#### TASK-2
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# %%
#### TASK-3

str_passout = StrOutputParser()

# %%
#### TASK-4
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str) -> dict:
    return{"text": text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %% [markdown]
# ### ***Parallel 1***

# %%
#### TASK-1

prompt_post = ChatPromptTemplate.from_messages([
    ("system", "You are a social media post generator"),
    ("human", "create a post for the following text for linkedIn {text}")

])

#### TASK-2
model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

#### TASK-
str_passout = StrOutputParser()

chain = prompt_post| model | str_passout

# %%
# #### CHAIN

# chain = prompt_template | model | str_passout | dictionary_maker_runnable | prompt_post | model | str_passout

# chain.invoke("What is the capical of france")

# %% [markdown]
# ### ***Parallel 2***

# %%
def insta_chain(text: dict):
    insta_post = ChatPromptTemplate.from_messages([
    ("system", "You are a social media post generator"),
    ("human", "create a post for the following text forTnstagram {text}")

    ])

    #### TASK-2
    model = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

    #### TASK-
    str_passout = StrOutputParser()

    insta_chain = insta_post | model | str_passout
