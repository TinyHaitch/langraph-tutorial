# %% [markdown]
# ### Model Integration with groq

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["OPENROUTER_API_KEY"]=os.getenv("OPEN_ROUTER_API")

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model('groq:llama-3.3-70b-versatile')
model
# Out:
# ChatGroq(metadata={'versions': {'langchain-core': '1.4.6', 'langchain': '1.3.7'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000002DC3F85EFC0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002DC3FC29FA0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
resonse = model.invoke("what is todays date")
resonse.content
# Out:
# "Today's date is June 15, 2026."

# %%
from langchain_groq import ChatGroq

modell = ChatGroq(model='llama-3.3-70b-versatile')
resonsee = modell.invoke("what is today date")
resonsee.content
# Out:
# "Today's date is June 15, 2026."
